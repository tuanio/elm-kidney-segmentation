# %%
# %run process_image.py configs/configs_brain.yaml

# %%
# %run process_image.py configs/configs_abdominal.yaml
# Out:
# (52, 230, 320)
# RMS Change: 0.012386228621553353
# Elapsed Iterations: 50
